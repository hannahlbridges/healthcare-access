# %%
import pandas as pd

# %%
state_spending_df = pd.read_csv('income_and_spending_data/usgs_state_2018.csv')

# %%
state_spending_df
# Out:
#    Comparison of State and Local Government Spending      Unnamed: 1  \
# 0                               in the United States             NaN
# 1                                   Fiscal Year 2018             NaN
# 2                               Amounts in $ million             NaN
# 3                                        Health Care             NaN
# 4                                              State  State Spending
# 5                                            Alabama        9,338.30
# 6                                             Alaska        2,369.00
# 7                                            Arizona       12,201.60
# 8                                           Arkansas        7,609.90
# 9                                         California      123,022.70
# 10                                          Colorado        9,687.90
# 11                                       Connecticut        4,980.40
# 12                                          Delaware        2,909.10
# ...
