# %%
import pandas as pd

# %%
average_cost_heart_attack_2013 = pd.read_csv("medicare_disparities/2013_average_cost_heart_attack.csv")
average_cost_heart_attack_2013
# Out:
#     year        geography                 measure         adjustment  \
# 0   2013  State/Territory  Average principal cost  Unsmoothed actual
# 1   2013  State/Territory  Average principal cost  Unsmoothed actual
# 2   2013  State/Territory  Average principal cost  Unsmoothed actual
# 3   2013  State/Territory  Average principal cost  Unsmoothed actual
# 4   2013  State/Territory  Average principal cost  Unsmoothed actual
# 5   2013  State/Territory  Average principal cost  Unsmoothed actual
# 6   2013  State/Territory  Average principal cost  Unsmoothed actual
# 7   2013  State/Territory  Average principal cost  Unsmoothed actual
# 8   2013  State/Territory  Average principal cost  Unsmoothed actual
# 9   2013  State/Territory  Average principal cost  Unsmoothed actual
# 10  2013  State/Territory  Average principal cost  Unsmoothed actual
# 11  2013  State/Territory  Average principal cost  Unsmoothed actual
# 12  2013  State/Territory  Average principal cost  Unsmoothed actual
# ...

# %%
average_cost_heart_attack_2018 = pd.read_csv("medicare_disparities/2018_average_cost_heart_attack.csv")
average_cost_heart_attack_2018
# Out:
#     year        geography                 measure         adjustment  \
# 0   2018  State/Territory  Average principal cost  Unsmoothed actual
# 1   2018  State/Territory  Average principal cost  Unsmoothed actual
# 2   2018  State/Territory  Average principal cost  Unsmoothed actual
# 3   2018  State/Territory  Average principal cost  Unsmoothed actual
# 4   2018  State/Territory  Average principal cost  Unsmoothed actual
# 5   2018  State/Territory  Average principal cost  Unsmoothed actual
# 6   2018  State/Territory  Average principal cost  Unsmoothed actual
# 7   2018  State/Territory  Average principal cost  Unsmoothed actual
# 8   2018  State/Territory  Average principal cost  Unsmoothed actual
# 9   2018  State/Territory  Average principal cost  Unsmoothed actual
# 10  2018  State/Territory  Average principal cost  Unsmoothed actual
# 11  2018  State/Territory  Average principal cost  Unsmoothed actual
# 12  2018  State/Territory  Average principal cost  Unsmoothed actual
# ...

# %%
average_cost_stroke_2018 = pd.read_csv("medicare_disparities/2018_average_cost_stroke.csv")
average_cost_stroke_2018
# Out:
#     year        geography                 measure         adjustment  \
# 0   2018  State/Territory  Average principal cost  Unsmoothed actual
# 1   2018  State/Territory  Average principal cost  Unsmoothed actual
# 2   2018  State/Territory  Average principal cost  Unsmoothed actual
# 3   2018  State/Territory  Average principal cost  Unsmoothed actual
# 4   2018  State/Territory  Average principal cost  Unsmoothed actual
# 5   2018  State/Territory  Average principal cost  Unsmoothed actual
# 6   2018  State/Territory  Average principal cost  Unsmoothed actual
# 7   2018  State/Territory  Average principal cost  Unsmoothed actual
# 8   2018  State/Territory  Average principal cost  Unsmoothed actual
# 9   2018  State/Territory  Average principal cost  Unsmoothed actual
# 10  2018  State/Territory  Average principal cost  Unsmoothed actual
# 11  2018  State/Territory  Average principal cost  Unsmoothed actual
# 12  2018  State/Territory  Average principal cost  Unsmoothed actual
# ...

# %%
average_cost_stroke_2013 = pd.read_csv("medicare_disparities/2013_average_cost_stroke.csv")
average_cost_stroke_2013
# Out:
#     year        geography                 measure         adjustment  \
# 0   2013  State/Territory  Average principal cost  Unsmoothed actual
# 1   2013  State/Territory  Average principal cost  Unsmoothed actual
# 2   2013  State/Territory  Average principal cost  Unsmoothed actual
# 3   2013  State/Territory  Average principal cost  Unsmoothed actual
# 4   2013  State/Territory  Average principal cost  Unsmoothed actual
# 5   2013  State/Territory  Average principal cost  Unsmoothed actual
# 6   2013  State/Territory  Average principal cost  Unsmoothed actual
# 7   2013  State/Territory  Average principal cost  Unsmoothed actual
# 8   2013  State/Territory  Average principal cost  Unsmoothed actual
# 9   2013  State/Territory  Average principal cost  Unsmoothed actual
# 10  2013  State/Territory  Average principal cost  Unsmoothed actual
# 11  2013  State/Territory  Average principal cost  Unsmoothed actual
# 12  2013  State/Territory  Average principal cost  Unsmoothed actual
# ...

# %%
readmissions_2018 = pd.read_csv("medicare_disparities/2018_readmissions.csv")
readmissions_2018
# Out:
#     year        geography       measure         adjustment      analysis  \
# 0   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 1   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 2   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 3   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 4   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 5   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 6   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 7   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 8   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 9   2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 10  2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 11  2018  State/Territory  Readmissions  Unsmoothed actual  Base measure
# ...

# %%
readmissions_2013 = pd.read_csv("medicare_disparities/2013_readmissions.csv")
readmissions_2013
# Out:
#     year        geography       measure         adjustment      analysis  \
# 0   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 1   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 2   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 3   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 4   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 5   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 6   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 7   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 8   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 9   2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 10  2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# 11  2013  State/Territory  Readmissions  Unsmoothed actual  Base measure
# ...

# %%
reimbursements_2018 = pd.read_csv("medicare_disparities/2018_medicare_reimbursements.csv")
reimbursements_2018
# Out:
#     year        geography                 measure         adjustment  \
# 0   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 1   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 2   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 3   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 4   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 5   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 6   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 7   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 8   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 9   2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 10  2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 11  2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 12  2018  State/Territory  Medicare Reimbursement  Unsmoothed actual
# ...

# %%
reimbursements_2013 = pd.read_csv("medicare_disparities/2013_medicare_reimbursements.csv")
reimbursements_2013
# Out:
#     year        geography                 measure         adjustment  \
# 0   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 1   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 2   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 3   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 4   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 5   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 6   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 7   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 8   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 9   2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 10  2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 11  2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# 12  2013  State/Territory  Medicare Reimbursement  Unsmoothed actual
# ...
