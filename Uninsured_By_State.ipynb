# %%
import pandas as pd

# %%
uninsured_by_state = pd.read_csv("Uninsured_by_State.csv")
uninsured_by_state.head(50)
# Out:
#    Table with row headers in column A and column headers in rows 6 through 10  \
# 0                                          Table A3.
# 1   Percentage of People Without Health Insurance ...
# 2   (Numbers in thousands. Civilian noninstitution...
# 3                                                 NaN
# 4                                               State
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                United States…………..
# 11                                                NaN
# 12                               Alabama……………………………….
# 13                             Alaska……………………………………..
# 14                             Arizona…………………………………..
# 15                              Arkansas……………………………….
# ...
