# %%
import pandas as pd

# %%
expansion_dates_df = pd.read_csv("medicaid_data/medicaid_expansion_dates.csv")
expansion_dates_df
# Out:
#                    State             Expansion Status Date Implemented
# 0                Alabama                  Not Adopted              NaN
# 1                 Alaska      Adopted and Implemented         9/1/2015
# 2                Arizona      Adopted and Implemented         1/1/2014
# 3               Arkansas      Adopted and Implemented         1/1/2014
# 4             California      Adopted and Implemented         1/1/2014
# 5               Colorado      Adopted and Implemented         1/1/2014
# 6            Connecticut      Adopted and Implemented         1/1/2014
# 7               Delaware      Adopted and Implemented         1/1/2014
# 8   District of Columbia      Adopted and Implemented         1/1/2014
# 9                Florida                  Not Adopted              NaN
# 10               Georgia                  Not Adopted              NaN
# 11                Hawaii      Adopted and Implemented         1/1/2014
# ...

# %%
enrollment_changes_df = pd.read_csv("medicaid_data/medicaid_expansion_enrollment_changes.csv")
enrollment_changes_df
## state data ends after row 53
# Out:
#                                              Location  \
# 0                                       United States
# 1                                             Alabama
# 2                                              Alaska
# 3                                             Arizona
# 4                                            Arkansas
# ..                                                ...
# 87  8. Oregon's Pre-ACA Average Monthly Enrollment...
# 88  9. Utah data includes individuals enrolled in ...
# 89  10. Washington data includes individuals enrol...
# 90  11. West Virginia data includes individuals en...
# 91  12. Wisconsin's Pre-ACA Average Monthly Enroll...
#
#     Pre-ACA Average Monthly Enrollment  \
# 0                           56511799.0
# 1                             799176.0
# 2                             122334.0
# 3                            1201770.0
# 4                             556851.0
# ..                                 ...
# ...

# %%
enrollment_data_df = pd.read_csv("medicaid_data/2019_01_Preliminary_applications__eligibility_determinations__and_enrollment_data.csv")
enrollment_data_df
# Out:
#    State Abbreviation            State Name Report Date  \
# 0                  CT           Connecticut    1/1/2019
# 1                  TN             Tennessee    1/1/2019
# 2                  MD              Maryland    1/1/2019
# 3                  NV                Nevada    1/1/2019
# 4                  WY               Wyoming    1/1/2019
# 5                  MN             Minnesota    1/1/2019
# 6                  WA            Washington    1/1/2019
# 7                  CA            California    1/1/2019
# 8                  CO              Colorado    1/1/2019
# 9                  ID                 Idaho    1/1/2019
# 10                 LA             Louisiana    1/1/2019
# 11                 AR              Arkansas    1/1/2019
# 12                 KY              Kentucky    1/1/2019
# 13                 NJ            New Jersey    1/1/2019
# 14                 OR                Oregon    1/1/2019
# 15                 ME                 Maine    1/1/2019
# ...
