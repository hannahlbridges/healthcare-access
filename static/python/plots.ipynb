# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import pearsonr 
from scipy.stats import linregress
# %matplotlib inline

# %%
state_data = pd.read_csv("final_dfs/state_data.csv")
state_data
# Out:
#              State  Expanded             Expansion Status Date Added  \
# 0          Alabama     False                  Not Adopted        NaN
# 1           Alaska      True      Adopted and Implemented   9/1/2015
# 2          Arizona      True      Adopted and Implemented   1/1/2014
# 3         Arkansas      True      Adopted and Implemented   1/1/2014
# 4       California      True      Adopted and Implemented   1/1/2014
# 5         Colorado      True      Adopted and Implemented   1/1/2014
# 6      Connecticut      True      Adopted and Implemented   1/1/2014
# 7         Delaware      True      Adopted and Implemented   1/1/2014
# 8          Florida     False                  Not Adopted        NaN
# 9          Georgia     False                  Not Adopted        NaN
# 10          Hawaii      True      Adopted and Implemented   1/1/2014
# 11           Idaho      True      Adopted and Implemented   1/1/2020
# 12        Illinois      True      Adopted and Implemented   1/1/2014
# 13         Indiana      True      Adopted and Implemented   2/1/2015
# 14            Iowa      True      Adopted and Implemented   1/1/2014
# 15          Kansas     False                  Not Adopted        NaN
# 16        Kentucky      True      Adopted and Implemented   1/1/2014
# 17       Louisiana      True      Adopted and Implemented   7/1/2016
# 18           Maine      True      Adopted and Implemented  1/10/2019
# 19        Maryland      True      Adopted and Implemented   1/1/2014
# 20   Massachusetts      True      Adopted and Implemented   1/1/2014
# 21        Michigan      True      Adopted and Implemented   4/1/2014
# 22       Minnesota      True      Adopted and Implemented   1/1/2014
# 23     Mississippi     False                  Not Adopted        NaN
# 24        Missouri      True  Adopted but Not Implemented   7/1/2021
# 25         Montana      True      Adopted and Implemented   1/1/2016
# 26        Nebraska      True      Adopted and Implemented  10/1/2020
# 27          Nevada      True      Adopted and Implemented   1/1/2014
# 28   New Hampshire      True      Adopted and Implemented  8/15/2014
# 29      New Jersey      True      Adopted and Implemented   1/1/2014
# 30      New Mexico      True      Adopted and Implemented   1/1/2014
# 31        New York      True      Adopted and Implemented   1/1/2014
# 32  North Carolina     False                  Not Adopted        NaN
# 33    North Dakota      True      Adopted and Implemented   1/1/2014
# 34            Ohio      True      Adopted and Implemented   1/1/2014
# 35        Oklahoma      True  Adopted but Not Implemented   7/1/2021
# 36          Oregon      True      Adopted and Implemented   1/1/2014
# 37    Pennsylvania      True      Adopted and Implemented   1/1/2015
# 38    Rhode Island      True      Adopted and Implemented   1/1/2014
# 39  South Carolina     False                  Not Adopted        NaN
# 40    South Dakota     False                  Not Adopted        NaN
# 41       Tennessee     False                  Not Adopted        NaN
# 42           Texas     False                  Not Adopted        NaN
# 43            Utah      True      Adopted and Implemented   1/1/2020
# 44         Vermont      True      Adopted and Implemented   1/1/2014
# 45        Virginia      True      Adopted and Implemented   1/1/2019
# 46      Washington      True      Adopted and Implemented   1/1/2014
# 47   West Virginia      True      Adopted and Implemented   1/1/2014
# 48       Wisconsin     False                  Not Adopted        NaN
# 49         Wyoming     False                  Not Adopted        NaN
#
#    Median Income State Spending Local Spending State and Local Spending  \
# 0         49,936       9,338.30       4,187.10                13,525.40
# 1         68,734       2,369.00          495.5                 2,864.50
# 2         62,283      12,201.60       1,007.80                13,209.40
# 3         49,781       7,609.90          296.8                 7,906.70
# 4         70,489     123,022.70      39,815.00               162,837.70
# 5         73,034       9,687.90       2,145.90                11,833.80
# 6         72,812       4,980.40          150.7                 5,131.00
# 7         65,012       2,909.10           39.5                 2,948.70
# 8         54,644      31,167.60      10,498.90                41,666.50
# 9         55,821      13,648.60       5,112.20                18,760.80
# 10        80,108       3,519.80           39.2                 3,559.00
# 11        58,728       2,502.00          803.6                 3,305.60
# 12        70,145      21,792.50       3,220.80                25,013.30
# 13        59,892      13,199.90       4,790.20                17,990.10
# 14        68,718       7,766.50       2,310.50                10,077.00
# 15        63,938       6,577.40       1,176.90                 7,754.40
# 16        54,555      13,139.60       1,108.20                14,247.80
# 17        49,973      12,184.70       2,737.00                14,921.60
# 18        58,663       2,698.80          157.7                 2,856.50
# 19        86,223      12,404.70          589.4                12,994.10
# 20        86,345      23,745.70       1,076.70                24,822.30
# 21        60,449      19,311.20       3,717.50                23,028.70
# 22        71,817      14,343.30       2,875.10                17,218.40
# 23        42,781       7,620.60       2,647.50                10,268.10
# 24        61,726      13,673.80       2,358.40                16,032.20
# 25        57,679       2,343.10          251.1                 2,594.20
# 26        67,575       2,477.20          755.8                 3,233.00
# 27        61,864       4,010.70       1,054.70                 5,065.40
# 28        81,346       2,029.60           24.9                 2,054.50
# 29        74,176      19,769.40          702.8                20,472.20
# 30        48,283       7,335.40          343.7                 7,679.10
# 31        67,274      71,940.60      16,192.50                88,133.10
# 32        53,369      16,786.20      11,540.60                28,326.90
# 33        66,505       1,411.10           69.5                 1,480.60
# 34        61,633      29,660.30       3,857.20                33,517.40
# 35        54,434       6,631.30       1,307.80                 7,939.10
# 36        69,165      10,067.00       1,367.20                11,434.30
# 37        64,524      31,587.60       4,101.20                35,688.80
# 38        62,266       3,152.80           20.3                 3,173.10
# 39        57,444      10,274.80       5,169.10                15,443.90
# 40        59,463          998.5          143.2                 1,141.70
# 41        56,060      11,117.90       4,161.00                15,278.90
# 42        59,785      43,925.20      15,505.50                59,430.70
# 43        77,067       5,512.10          806.9                 6,319.00
# 44        70,066       1,526.60            9.7                 1,536.30
# 45        77,151      16,593.80       1,692.90                18,286.70
# 46        79,726      16,549.10       5,001.30                21,550.40
# 47        50,573       4,273.60          377.5                 4,651.20
# 48        62,629      12,390.40       1,180.20                13,570.60
# 49        62,539       1,060.10       1,236.90                 2,297.00
#
#     Population-millions  2010 Uninsured  2018 Uninsured  2019 Uninsured
# 0                   4.9            14.6            10.0             9.7
# 1                   0.7            19.9            12.6            12.2
# 2                   7.2            16.9            10.6            11.3
# 3                   3.0            17.5             8.2             9.1
# 4                  39.5            18.5             7.2             7.7
# 5                   5.7            15.9             7.5             8.0
# 6                   3.6             9.1             5.3             5.9
# 7                   1.0             9.7             5.7             6.6
# 8                  21.2            21.3            13.0            13.2
# 9                  10.5            19.7            13.7            13.4
# 10                  1.4             7.9             4.1             4.2
# 11                  1.8            17.7            11.1            10.8
# 12                 12.7            13.8             7.0             7.4
# 13                  6.7            14.8             8.3             8.7
# 14                  3.1             9.3             4.7             5.0
# 15                  2.9            13.9             8.8             9.2
# 16                  4.5            15.3             5.6             6.4
# 17                  4.7            17.8             8.0             8.9
# 18                  1.3            10.1             8.0             8.0
# 19                  6.0            11.3             6.0             6.0
# 20                  6.9             4.4             2.8             3.0
# 21                 10.0            12.4             5.4             5.8
# 22                  5.6             9.1             4.4             4.9
# 23                  3.0            18.2            12.1            13.0
# 24                  6.1            13.2             9.4            10.0
# 25                  1.1            17.3             8.2             8.3
# 26                  1.9            11.5             8.3             8.3
# 27                  3.0            22.6            11.2            11.4
# 28                  1.4            11.1             5.7             6.3
# 29                  8.9            13.2             7.4             7.9
# 30                  2.1            19.6             9.5            10.0
# 31                 19.5            11.9             5.4             5.2
# 32                 10.4            16.8            10.7            11.3
# 33                  0.8             9.8             7.3             6.9
# 34                 11.7            12.3             6.5             6.6
# 35                  3.9            18.9            14.2            14.3
# 36                  4.2            17.1             7.1             7.2
# 37                 12.8            10.2             5.5             5.8
# 38                  1.1            12.2             4.1             4.1
# 39                  5.1            17.5            10.5            10.8
# 40                  0.9            12.4             9.8            10.2
# 41                  6.8            14.4            10.1            10.1
# 42                 28.6            23.7            17.7            18.4
# 43                  3.2            15.3             9.4             9.7
# 44                  0.6             8.0             4.0             4.5
# 45                  8.5            13.1             8.8             7.9
# 46                  7.5            14.2             6.4             6.6
# 47                  1.8            14.6             6.4             6.7
# 48                  5.8             9.4             5.5             5.7
# 49                  0.6            14.9            10.5            12.3

# %%
coverage = pd.read_csv('final_dfs/coverage_type.csv')
coverage.head()
# Out:
#         State  Employer  Marketplace/Private  Medicaid  Medicare  Military  \
# 0     Alabama     0.472                0.055     0.195     0.160     0.021
# 1      Alaska     0.484                0.035     0.213     0.100     0.053
# 2     Arizona     0.451                0.052     0.210     0.161     0.015
# 3    Arkansas     0.420                0.054     0.262     0.159     0.014
# 4  California     0.480                0.066     0.253     0.114     0.009
#
#    Uninsured
# 0      0.097
# 1      0.115
# 2      0.111
# 3      0.091
# 4      0.078

# %%
labels = ['Marketplace/Private', 'Medicaid', 'Medicare', 'Military','Uninsured']
sizes = coverage[['Marketplace/Private', 'Medicaid', 'Medicare', 'Military', 'Uninsured']].iloc[33]
plt.pie(sizes, labels=labels, colors=['green', 'blue', 'purple', 'red'], autopct="%1.1f%%", startangle=45,)
plt.title('Percent of North Carolina Citizens by Coverage Type')
plt.legend(loc='lower right')
plt.savefig('coverage_type.png')

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f987803193e3> in <module>
#       1 uninsured = state_data[['2010 Uninsured', "2018 Uninsured", '2019 Uninsured']]
# ----> 2 uninsured.plot(kind='line', color='blue', xlabel='Year', ylabel='Percent Uninsured', title='Percent Uninsured Over Time')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1083                 stacking_id=stacking_id,
#    1084                 is_errorbar=is_errorbar,
# -> 1085                 **kwds,
#    1086             )
#    1087             self._add_legend_handle(newlines[0], label, index=i)
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1102             cls._initialize_stacker(ax, stacking_id, len(y))
#    1103         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1104         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1105         cls._update_stacker(ax, stacking_id, y)
#    1106         return lines
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      64     def wrapper(*args, **kwargs):
#      65         with pandas_converters():
# ---> 66             return func(*args, **kwargs)
#      67
#      68     return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     654             else:
#     655                 args = (x, y)
# --> 656             return ax.plot(*args, **kwds)
#     657
#     658     def _get_index_name(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1663         """
#    1664         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1665         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1666         for line in lines:
#    1667             self.add_line(line)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     403                 "non-matching shapes is deprecated.")
#     404         for j in range(max(ncx, ncy)):
# --> 405             seg = func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     406             ret.append(seg)
#     407         return ret
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     310         default_dict = self._getdefaults(set(), kw)
#     311         self._setdefaults(default_dict, kw)
# --> 312         seg = mlines.Line2D(x, y, **kw)
#     313         return seg
#     314
#
# ~\anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     402         # update kwargs before updating data to give the caller a
#     403         # chance to init axes (and hence unit support)
# --> 404         self.update(kwargs)
#     405         self.pickradius = pickradius
#     406         self.ind_offset = 0
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#     972
#     973         with cbook._setattr_cm(self, eventson=False):
# --> 974             ret = [_update_property(self, k, v) for k, v in props.items()]
#     975
#     976         if len(ret):
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     968                 if not callable(func):
#     969                     raise AttributeError('{!r} object has no property {!r}'
# --> 970                                          .format(type(self).__name__, k))
#     971                 return func(v)
#     972
#
# AttributeError: 'Line2D' object has no property 'xlabel'
