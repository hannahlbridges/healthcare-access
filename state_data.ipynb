# %%
import pandas as pd

# %%
median_income_df = pd.read_csv('income_and_spending_data/median_income_2018.csv')
median_income_df
expansion_dates_df = pd.read_csv("medicaid_data/medicaid_expansion_dates.csv")
expansion_dates_df
median_income_df = pd.read_csv('income_and_spending_data/median_income_2018.csv')
median_income_df
state_spending_df = pd.read_csv('income_and_spending_data/usgs_state_2018.csv')
expansion_dates_df
# Out:
#                    State             Expansion Status Date Implemented
# 0                Alabama                  Not Adopted              NaN
# 1                 Alaska      Adopted and Implemented         9/1/2015
# 2                Arizona      Adopted and Implemented         1/1/2014
# 3               Arkansas      Adopted and Implemented         1/1/2014
# 4             California      Adopted and Implemented         1/1/2014
# 5               Colorado      Adopted and Implemented         1/1/2014
# 6            Connecticut      Adopted and Implemented         1/1/2014
# 7               Delaware      Adopted and Implemented         1/1/2014
# 8   District of Columbia      Adopted and Implemented         1/1/2014
# 9                Florida                  Not Adopted              NaN
# 10               Georgia                  Not Adopted              NaN
# 11                Hawaii      Adopted and Implemented         1/1/2014
# ...

# %%
state_data = expansion_dates_df.merge(right=median_income_df, on="State")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-e11176c5a7d2> in <module>
# ----> 1 state_data = expansion_dates_df.merge(right=median_income_df, on="State")
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    7295             copy=copy,
#    7296             indicator=indicator,
# -> 7297             validate=validate,
#    7298         )
#    7299
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      84         copy=copy,
#      85         indicator=indicator,
# ---> 86         validate=validate,
#      87     )
# ...
