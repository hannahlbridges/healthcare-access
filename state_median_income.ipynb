# %%
import pandas as pd

# %%
median_income_df = pd.read_csv('income_and_spending_data/median_income_2018.csv')

# %%
median_income_df
# Out:
#             State  Median Income Standard Error
# 0    United States        63,179            420
# 1          Alabama        49,936          2,423
# 2           Alaska        68,734          3,390
# 3          Arizona        62,283          2,291
# 4         Arkansas        49,781          2,108
# 5       California        70,489          1,233
# 6         Colorado        73,034          3,562
# 7      Connecticut        72,812          5,119
# 8         Delaware        65,012          3,599
# 9             D.C.        85,750          2,659
# 10         Florida        54,644          1,887
# 11         Georgia        55,821          2,032
# 12          Hawaii        80,108          3,482
# 13           Idaho        58,728          2,405
# 14        Illinois        70,145          2,253
# 15         Indiana        59,892          1,997
# 16            Iowa        68,718          2,910
# 17          Kansas        63,938          2,027
# 18        Kentucky        54,555          3,668
# ...
