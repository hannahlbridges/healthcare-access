# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
coverage_type_df = pd.read_csv("insurance_coverage_type_2019.csv")
coverage_type_df
# Out:
#                    State  Employer  Marketplace/Private  Medicaid  Medicare  \
# 0          United States     0.496                0.059     0.198     0.142
# 1                Alabama     0.472                0.055     0.195     0.160
# 2                 Alaska     0.484                0.035     0.213     0.100
# 3                Arizona     0.451                0.052     0.210     0.161
# 4               Arkansas     0.420                0.054     0.262     0.159
# 5             California     0.480                0.066     0.253     0.114
# 6               Colorado     0.534                0.069     0.168     0.128
# 7            Connecticut     0.529                0.048     0.215     0.141
# 8               Delaware     0.497                0.041     0.204     0.173
# 9   District of Columbia     0.549                0.065     0.255     0.082
# 10               Florida     0.403                0.095     0.174     0.180
# ...

# %%
coverage_type_df.to_csv('final_dfs/coverage_type.csv', index=False)

# %%
engine = create_engine('postgres://utlwaavyjuxofx:2a4c69f3bd75609ebd38e1baa22d0c7401379461eeb4ccd1eb50ab45b9abe361@ec2-54-156-73-147.compute-1.amazonaws.com:5432/d6n2aueo5t3uht')

# %%
coverage_type_df.to_sql('coverage_type_percents', con=engine, index=False)
